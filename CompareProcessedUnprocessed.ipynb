# %%
import pandas as pd

# %%
df_orig = pd.read_csv("20230111-DataSheet-RUN51.csv", skiprows=20)
df_orig.head()
# Out:
#    Sample_ID            Sample_Name  Sample_Plate  Sample_Well  I7_Index_ID  \
# 0  N701_S502  AN1-ESRA-d90-blood-Bk           NaN          NaN          NaN
# 1  N702_S502  AN2-ESRA-d90-blood-Bk           NaN          NaN          NaN
# 2  N703_S502  AN3-ESRA-d90-blood-Bk           NaN          NaN          NaN
# 3  N704_S502  AN4-ESRA-d90-blood-Bk           NaN          NaN          NaN
# 4  N705_S502  AN5-ESRA-d90-blood-Bk           NaN          NaN          NaN
#
#    index  I5_Index_ID  index2  Run  Nr  ... Species Chain Patient  \
# 0    NaN          NaN     NaN  NaN  S1  ...   mouse  BCRk     AN1
# 1    NaN          NaN     NaN  NaN  S2  ...   mouse  BCRk     AN2
# 2    NaN          NaN     NaN  NaN  S3  ...   mouse  BCRk     AN3
# 3    NaN          NaN     NaN  NaN  S4  ...   mouse  BCRk     AN4
# 4    NaN          NaN     NaN  NaN  S5  ...   mouse  BCRk     AN5
#
#         Sample  UMI MID  Constant HEK_cells Group RACE
# 0  Blood-day90  yes NaN        no        no  ESRA   no
# 1  Blood-day90  yes NaN        no        no  ESRA   no
# 2  Blood-day90  yes NaN        no        no  ESRA   no
# 3  Blood-day90  yes NaN        no        no  ESRA   no
# 4  Blood-day90  yes NaN        no        no  ESRA   no
#
# [5 rows x 21 columns]

# %%
# Preparation: ls /mnt/immunogenomics/RUNS/$RUN/$OUTDIR/final/*-clones-mut-sites.csv > list-processed.txt
df_processed = pd.read_csv("list-processed.txt", header=None)
df_processed.columns = ['filename']
df_processed.head()
# Out:
#                                             filename
# 0  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 1  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 2  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 3  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 4  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...

# %%
get_sample = lambda x: x.split("/")[-1].split('_')[0]
df_processed['Sample_Name'] = [x for x in map(get_sample, df_processed['filename'])]
df_processed.head()
# Out:
#                                             filename           Sample_Name
# 0  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...   A1-ERO-d21-blood-Bk
# 1  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...     A1-ESRA-d90-SP-Bk
# 2  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...  A1-ESRA-d90-blood-Bk
# 3  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...  A1-ESRO-d21-blood-Bk
# 4  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...     A1-VERO-d21-BM-Bk

# %%
df = pd.merge(df_orig, df_processed, how='left', on='Sample_Name')
df
# Out:
#      Sample_ID            Sample_Name  Sample_Plate  Sample_Well  I7_Index_ID  \
# 0    N701_S502  AN1-ESRA-d90-blood-Bk           NaN          NaN          NaN
# 1    N702_S502  AN2-ESRA-d90-blood-Bk           NaN          NaN          NaN
# 2    N703_S502  AN3-ESRA-d90-blood-Bk           NaN          NaN          NaN
# 3    N704_S502  AN4-ESRA-d90-blood-Bk           NaN          NaN          NaN
# 4    N705_S502  AN5-ESRA-d90-blood-Bk           NaN          NaN          NaN
# 5    N706_S502   A1-ESRA-d90-blood-Bk           NaN          NaN          NaN
# 6    N707_S502   A2-ESRA-d90-blood-Bk           NaN          NaN          NaN
# 7    N710_S502   A3-ESRA-d90-blood-Bk           NaN          NaN          NaN
# 8    N711_S502      B3-ESRA-d90-LN-Bk           NaN          NaN          NaN
# 9    N712_S502      B4-ESRA-d90-LN-Bk           NaN          NaN          NaN
# 10   N714_S502      B5-ESRA-d90-LN-Bk           NaN          NaN          NaN
# 11   N715_S502      B1-ESRA-d90-BM-Bk           NaN          NaN          NaN
# 12   N716_S502      B2-ESRA-d90-BM-Bk           NaN          NaN          NaN
# 13   N718_S502      B3-ESRA-d90-BM-Bk           NaN          NaN          NaN
# 14   N719_S502      B4-ESRA-d90-BM-Bk           NaN          NaN          NaN
# 15   N720_S502      B5-ESRA-d90-BM-Bk           NaN          NaN          NaN
# 16   N701_S503   A4-ESRA-d90-blood-Bk           NaN          NaN          NaN
# 17   N702_S503   A5-ESRA-d90-blood-Bk           NaN          NaN          NaN
# 18   N703_S503      A1-ESRA-d90-SP-Bk           NaN          NaN          NaN
# 19   N704_S503      A2-ESRA-d90-SP-Bk           NaN          NaN          NaN
# 20   N705_S503      A3-ESRA-d90-SP-Bk           NaN          NaN          NaN
# 21   N706_S503      A4-ESRA-d90-SP-Bk           NaN          NaN          NaN
# 22   N707_S503      A5-ESRA-d90-SP-Bk           NaN          NaN          NaN
# 23   N710_S503   A1-VERO-d21-blood-Bk           NaN          NaN          NaN
# 24   N711_S503     BN1-ESRA-d90-LN-Bk           NaN          NaN          NaN
# 25   N712_S503     BN2-ESRA-d90-LN-Bk           NaN          NaN          NaN
# 26   N714_S503     BN3-ESRA-d90-LN-Bk           NaN          NaN          NaN
# 27   N715_S503     BN4-ESRA-d90-LN-Bk           NaN          NaN          NaN
# 28   N716_S503     BN5-ESRA-d90-LN-Bk           NaN          NaN          NaN
# 29   N718_S503       B2-ERA-d45-SP-Bk           NaN          NaN          NaN
# ..         ...                    ...           ...          ...          ...
# 139  N712_S515            Bx1689-ST-T           NaN          NaN          NaN
# 140  N715_S515            BB5376-ST-T           NaN          NaN          NaN
# 141  N716_S515            BB5347-ST-T           NaN          NaN          NaN
# 142  N718_S515            BB4753-ST-T           NaN          NaN          NaN
# 143  N719_S515            BB4554-ST-T           NaN          NaN          NaN
# 144  N720_S515           BB5661-ST-T2           NaN          NaN          NaN
# 145  N701_S516      B3-ESRO-d90-LN-Bk           NaN          NaN          NaN
# 146  N702_S516      B1-ESRO-d90-BM-Bk           NaN          NaN          NaN
# 147  N703_S516      B2-ESRO-d90-BM-Bk           NaN          NaN          NaN
# 148  N704_S516      B3-ESRO-d90-BM-Bk           NaN          NaN          NaN
# 149  N705_S516       B1-ERA-d45-LN-Bk           NaN          NaN          NaN
# 150  N706_S516       B2-ERA-d45-LN-Bk           NaN          NaN          NaN
# 151  N707_S516       B3-ERA-d45-LN-Bk           NaN          NaN          NaN
# 152  N710_S516       B4-ERA-d45-LN-Bk           NaN          NaN          NaN
# 153  N711_S516            BB5546-ST-T           NaN          NaN          NaN
# 154  N712_S516            BB4382-ST-T           NaN          NaN          NaN
# 155  N716_S516            BB3709-ST-T           NaN          NaN          NaN
# 156  N718_S516           BB5238-ST-T2           NaN          NaN          NaN
# 157  N719_S516            Bx1304-ST-T           NaN          NaN          NaN
# 158  N720_S516            Bx1429-ST-T           NaN          NaN          NaN
# 159  N701_S517       B5-ERA-d45-LN-Bk           NaN          NaN          NaN
# 160  N702_S517       B1-ERA-d45-BM-Bk           NaN          NaN          NaN
# 161  N703_S517       B2-ERA-d45-BM-Bk           NaN          NaN          NaN
# 162  N704_S517       B3-ERA-d45-BM-Bk           NaN          NaN          NaN
# 163  N705_S517       B4-ERA-d45-BM-Bk           NaN          NaN          NaN
# 164  N706_S517       B5-ERA-d45-BM-Bk           NaN          NaN          NaN
# 165  N707_S517      B1-ESRA-d90-LN-Bk           NaN          NaN          NaN
# 166  N710_S517      B2-ESRA-d90-LN-Bk           NaN          NaN          NaN
# 167  N719_S517            BB6423-ST-T           NaN          NaN          NaN
# 168  N720_S517            BB6649-ST-T           NaN          NaN          NaN
#
#      index  I5_Index_ID  index2  Run    Nr  ... Chain Patient       Sample  \
# 0      NaN          NaN     NaN  NaN    S1  ...  BCRk     AN1  Blood-day90
# 1      NaN          NaN     NaN  NaN    S2  ...  BCRk     AN2  Blood-day90
# 2      NaN          NaN     NaN  NaN    S3  ...  BCRk     AN3  Blood-day90
# 3      NaN          NaN     NaN  NaN    S4  ...  BCRk     AN4  Blood-day90
# 4      NaN          NaN     NaN  NaN    S5  ...  BCRk     AN5  Blood-day90
# 5      NaN          NaN     NaN  NaN    S6  ...  BCRk      A1  Blood-day90
# 6      NaN          NaN     NaN  NaN    S7  ...  BCRk      A2  Blood-day90
# 7      NaN          NaN     NaN  NaN    S8  ...  BCRk      A3  Blood-day90
# 8      NaN          NaN     NaN  NaN    S9  ...  BCRk      B3     LN-day90
# 9      NaN          NaN     NaN  NaN   S10  ...  BCRk      B4     LN-day90
# 10     NaN          NaN     NaN  NaN   S11  ...  BCRk      B5     LN-day90
# 11     NaN          NaN     NaN  NaN   S12  ...  BCRk      B1     BM-day90
# 12     NaN          NaN     NaN  NaN   S13  ...  BCRk      B2     BM-day90
# 13     NaN          NaN     NaN  NaN   S14  ...  BCRk      B3     BM-day90
# 14     NaN          NaN     NaN  NaN   S15  ...  BCRk      B4     BM-day90
# 15     NaN          NaN     NaN  NaN   S16  ...  BCRk      B5     BM-day90
# 16     NaN          NaN     NaN  NaN   S17  ...  BCRk      A4  Blood-day90
# 17     NaN          NaN     NaN  NaN   S18  ...  BCRk      A5  Blood-day90
# 18     NaN          NaN     NaN  NaN   S19  ...  BCRk      A1     SP-day90
# 19     NaN          NaN     NaN  NaN   S20  ...  BCRk      A2     SP-day90
# 20     NaN          NaN     NaN  NaN   S21  ...  BCRk      A3     SP-day90
# 21     NaN          NaN     NaN  NaN   S22  ...  BCRk      A4     SP-day90
# 22     NaN          NaN     NaN  NaN   S23  ...  BCRk      A5     SP-day90
# 23     NaN          NaN     NaN  NaN   S24  ...  BCRk      A1  Blood-day21
# 24     NaN          NaN     NaN  NaN   S25  ...  BCRk     BN1     LN-day90
# 25     NaN          NaN     NaN  NaN   S26  ...  BCRk     BN2     LN-day90
# 26     NaN          NaN     NaN  NaN   S27  ...  BCRk     BN3     LN-day90
# 27     NaN          NaN     NaN  NaN   S28  ...  BCRk     BN4     LN-day90
# 28     NaN          NaN     NaN  NaN   S29  ...  BCRk     BN5     LN-day90
# 29     NaN          NaN     NaN  NaN   S30  ...  BCRk      B2     SP-day45
# ..     ...          ...     ...  ...   ...  ...   ...     ...          ...
# 139    NaN          NaN     NaN  NaN  S140  ...  TCRb  Bx1689           ST
# 140    NaN          NaN     NaN  NaN  S141  ...  TCRb  BB5376           ST
# 141    NaN          NaN     NaN  NaN  S142  ...  TCRb  BB5347           ST
# 142    NaN          NaN     NaN  NaN  S143  ...  TCRb  BB4753           ST
# 143    NaN          NaN     NaN  NaN  S144  ...  TCRb  BB4554           ST
# 144    NaN          NaN     NaN  NaN  S145  ...  TCRb  BB5661           ST
# 145    NaN          NaN     NaN  NaN  S146  ...  BCRk      B3     LN-day90
# 146    NaN          NaN     NaN  NaN  S147  ...  BCRk      B1     BM-day90
# 147    NaN          NaN     NaN  NaN  S148  ...  BCRk      B2     BM-day90
# 148    NaN          NaN     NaN  NaN  S149  ...  BCRk      B3     BM-day90
# 149    NaN          NaN     NaN  NaN  S150  ...  BCRk      B1     LN-day45
# 150    NaN          NaN     NaN  NaN  S151  ...  BCRk      B2     LN-day45
# 151    NaN          NaN     NaN  NaN  S152  ...  BCRk      B3     LN-day45
# 152    NaN          NaN     NaN  NaN  S153  ...  BCRk      B4     LN-day45
# 153    NaN          NaN     NaN  NaN  S154  ...  TCRb  BB5546           ST
# 154    NaN          NaN     NaN  NaN  S155  ...  TCRb  BB4382           ST
# 155    NaN          NaN     NaN  NaN  S156  ...  TCRb  BB3709           ST
# 156    NaN          NaN     NaN  NaN  S157  ...  TCRb  BB5238           ST
# 157    NaN          NaN     NaN  NaN  S158  ...  TCRb  Bx1304           ST
# 158    NaN          NaN     NaN  NaN  S159  ...  TCRb  Bx1429           ST
# 159    NaN          NaN     NaN  NaN  S160  ...  BCRk      B5     LN-day45
# 160    NaN          NaN     NaN  NaN  S161  ...  BCRk      B1     BM-day45
# 161    NaN          NaN     NaN  NaN  S162  ...  BCRk      B2     BM-day45
# 162    NaN          NaN     NaN  NaN  S163  ...  BCRk      B3     BM-day45
# 163    NaN          NaN     NaN  NaN  S164  ...  BCRk      B4     BM-day45
# 164    NaN          NaN     NaN  NaN  S165  ...  BCRk      B5     BM-day45
# 165    NaN          NaN     NaN  NaN  S166  ...  BCRk      B1     LN-day90
# 166    NaN          NaN     NaN  NaN  S167  ...  BCRk      B2     LN-day90
# 167    NaN          NaN     NaN  NaN  S168  ...  TCRb  BB6423           ST
# 168    NaN          NaN     NaN  NaN  S169  ...  TCRb  BB6649           ST
#
#      UMI MID Constant  HEK_cells Group RACE  \
# 0    yes NaN       no         no  ESRA   no
# 1    yes NaN       no         no  ESRA   no
# 2    yes NaN       no         no  ESRA   no
# 3    yes NaN       no         no  ESRA   no
# 4    yes NaN       no         no  ESRA   no
# 5    yes NaN       no         no  ESRA   no
# 6    yes NaN       no         no  ESRA   no
# 7    yes NaN       no         no  ESRA   no
# 8    yes NaN       no         no  ESRA   no
# 9    yes NaN       no         no  ESRA   no
# 10   yes NaN       no         no  ESRA   no
# 11   yes NaN       no         no  ESRA   no
# 12   yes NaN       no         no  ESRA   no
# 13   yes NaN       no         no  ESRA   no
# 14   yes NaN       no         no  ESRA   no
# 15   yes NaN       no         no  ESRA   no
# 16   yes NaN       no         no  ESRA   no
# 17   yes NaN       no         no  ESRA   no
# 18   yes NaN       no         no  ESRA   no
# 19   yes NaN       no         no  ESRA   no
# 20   yes NaN       no         no  ESRA   no
# 21   yes NaN       no         no  ESRA   no
# 22   yes NaN       no         no  ESRA   no
# 23   yes NaN       no         no  VERO   no
# 24   yes NaN       no         no  ESRA   no
# 25   yes NaN       no         no  ESRA   no
# 26   yes NaN       no         no  ESRA   no
# 27   yes NaN       no         no  ESRA   no
# 28   yes NaN       no         no  ESRA   no
# 29   yes NaN       no         no   ERA   no
# ..   ...  ..      ...        ...   ...  ...
# 139  yes NaN       no        yes   NaN   no
# 140  yes NaN       no        yes   NaN   no
# 141  yes NaN       no        yes   NaN   no
# 142  yes NaN       no        yes   NaN   no
# 143  yes NaN       no        yes   NaN   no
# 144  yes NaN       no        yes   NaN   no
# 145  yes NaN       no         no  ESRO   no
# 146  yes NaN       no         no  ESRO   no
# 147  yes NaN       no         no  ESRO   no
# 148  yes NaN       no         no  ESRO   no
# 149  yes NaN       no         no   ERA   no
# 150  yes NaN       no         no   ERA   no
# 151  yes NaN       no         no   ERA   no
# 152  yes NaN       no         no   ERA   no
# 153  yes NaN       no        yes   NaN   no
# 154  yes NaN       no        yes   NaN   no
# 155  yes NaN       no        yes   NaN   no
# 156  yes NaN       no        yes   NaN   no
# 157  yes NaN       no        yes   NaN   no
# 158  yes NaN       no        yes   NaN   no
# 159  yes NaN       no         no   ERA   no
# 160  yes NaN       no         no   ERA   no
# 161  yes NaN       no         no   ERA   no
# 162  yes NaN       no         no   ERA   no
# 163  yes NaN       no         no   ERA   no
# 164  yes NaN       no         no   ERA   no
# 165  yes NaN       no         no  ESRA   no
# 166  yes NaN       no         no  ESRA   no
# 167  yes NaN       no        yes   NaN   no
# 168  yes NaN       no        yes   NaN   no
#
#                                               filename
# 0    /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 1    /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 2    /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 3    /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 4    /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 5    /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 6                                                  NaN
# 7                                                  NaN
# 8    /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 9                                                  NaN
# 10                                                 NaN
# 11   /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 12                                                 NaN
# 13   /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 14                                                 NaN
# 15   /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 16                                                 NaN
# 17   /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 18   /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22   /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 23   /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28   /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 29                                                 NaN
# ..                                                 ...
# 139                                                NaN
# 140  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 141  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 142  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 143  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 144  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 145  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 146                                                NaN
# 147                                                NaN
# 148  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 149  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 150                                                NaN
# 151  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 152  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 153  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 154  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 155  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 156  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 157                                                NaN
# 158                                                NaN
# 159  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 160  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 161                                                NaN
# 162  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 163  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 164  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 165  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 166                                                NaN
# 167  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 168  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
#
# [169 rows x 22 columns]

# %%
# Get list of unprocessed samples
df = df[df['filename'].isna()]
len(df)
# Out:
# 80

# %%
# Preparation: ls /mnt/immunogenomics/RUNS/$RUN/data/raw/*.fastq.gz > list-fastq.txt
df_fastq = pd.read_csv("list-fastq.txt", header=None)
df_fastq.columns = ['fastq']
df_fastq.head()
# Out:
#                                                fastq
# 0  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 1  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 2  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 3  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 4  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...

# %%
get_sample = lambda x: x.split("/")[-1].split('_')[0]
df_fastq['Sample_Name'] = [x for x in map(get_sample, df_fastq['fastq'])]
df_fastq.head()
# Out:
#                                                fastq           Sample_Name
# 0  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...   A1-ERO-d21-blood-Bk
# 1  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...   A1-ERO-d21-blood-Bk
# 2  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...     A1-ESRA-d90-SP-Bk
# 3  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...     A1-ESRA-d90-SP-Bk
# 4  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...  A1-ESRA-d90-blood-Bk

# %%
# Combined list unprocessed samples with fastq paths
df = pd.merge(df, df_fastq, how='left', on='Sample_Name')
df.head()
# Out:
#    Sample_ID           Sample_Name  Sample_Plate  Sample_Well  I7_Index_ID  \
# 0  N707_S502  A2-ESRA-d90-blood-Bk           NaN          NaN          NaN
# 1  N707_S502  A2-ESRA-d90-blood-Bk           NaN          NaN          NaN
# 2  N710_S502  A3-ESRA-d90-blood-Bk           NaN          NaN          NaN
# 3  N710_S502  A3-ESRA-d90-blood-Bk           NaN          NaN          NaN
# 4  N712_S502     B4-ESRA-d90-LN-Bk           NaN          NaN          NaN
#
#    index  I5_Index_ID  index2  Run   Nr  ... Patient       Sample  UMI MID  \
# 0    NaN          NaN     NaN  NaN   S7  ...      A2  Blood-day90  yes NaN
# 1    NaN          NaN     NaN  NaN   S7  ...      A2  Blood-day90  yes NaN
# 2    NaN          NaN     NaN  NaN   S8  ...      A3  Blood-day90  yes NaN
# 3    NaN          NaN     NaN  NaN   S8  ...      A3  Blood-day90  yes NaN
# 4    NaN          NaN     NaN  NaN  S10  ...      B4     LN-day90  yes NaN
#
#   Constant HEK_cells  Group RACE filename  \
# 0       no        no   ESRA   no      NaN
# 1       no        no   ESRA   no      NaN
# 2       no        no   ESRA   no      NaN
# 3       no        no   ESRA   no      NaN
# 4       no        no   ESRA   no      NaN
#
#                                                fastq
# 0  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 1  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 2  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 3  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
# 4  /mnt/immunogenomics/RUNS/run51-20221213-miseq/...
#
# [5 rows x 23 columns]

# %%
len(df)
# Out:
# 160

# %%
# Check which reference should be used
df.groupby(['Species', 'Chain', 'UMI', 'Constant', 'RACE']).agg({'Sample_Name': 'nunique'})
# Out:
#                                  Sample_Name
# Species Chain UMI Constant RACE
# human   TCRb  yes no       no             16
# mouse   BCRk  yes no       no             64

# %%
df_human_TCRb = df[(df['Species'] == 'human') & (df['Chain'] == "TCRb")]
df_mouse_BCRk = df[(df['Species'] == 'mouse') & (df['Chain'] == "BCRk")]

# %%
df_human_TCRb = df_human_TCRb['fastq']
df_mouse_BCRk = df_mouse_BCRk['fastq']

# %%
df_human_TCRb.to_csv("SAMPLES-human-TCRb", header=False, index=False)
df_mouse_BCRk.to_csv("SAMPLES-mouse-BCRk", header=False, index=False)
