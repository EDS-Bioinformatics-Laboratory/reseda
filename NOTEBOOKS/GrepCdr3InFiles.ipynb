# %%
import os
import pandas as pd
import subprocess
import re

# %%
# Test grep
cmd = ["grep", "CARDLG", "2020-08-21.presyn-top100-clones-contamination-table-on-pt.csv"]
rc = subprocess.run(cmd, stdout=subprocess.PIPE)
print(rc.stdout)
# Out:
# b'"42","CARDLGCSGGSCYADYYYYGMDVWGQGTTVT x","RA-min-3 LN99-run81-r2_S6__RA-min-1 LN97-run81-r2_S4__RA-plus-4 LN96-run81-r2_S244"\r\n"70","CARDLGYRAFDYWGQGTLVT x","RA-min-5 LN85-run181-r2_S228__RA-min-5 LN85-run162-r2_S132__RA-min-5 LN85-run160-r4_S107__RA-min-5 LN85-run141-r2_S34__RA-plus-6 LN70-run160-r4_S96"\r\n'

# %%
# Get the directory names of the Roche runs and put it in 'runlist'
mydir = "/mnt/immunogenomics/RUNS/"
p = re.compile('run\d+')
runlist = list()
for rundir in os.listdir(mydir):
    m = p.match(rundir)
    if m != None:
        if m.group() == rundir:
            runlist.append(mydir + rundir + "/")

# %%
runlist.sort()
runlist
# Out:
# ['/mnt/immunogenomics/RUNS/run102/',
#  '/mnt/immunogenomics/RUNS/run112/',
#  '/mnt/immunogenomics/RUNS/run114/',
#  '/mnt/immunogenomics/RUNS/run122/',
#  '/mnt/immunogenomics/RUNS/run141/',
#  '/mnt/immunogenomics/RUNS/run142/',
#  '/mnt/immunogenomics/RUNS/run157/',
#  '/mnt/immunogenomics/RUNS/run160/',
#  '/mnt/immunogenomics/RUNS/run162/',
#  '/mnt/immunogenomics/RUNS/run169/',
#  '/mnt/immunogenomics/RUNS/run181/',
#  '/mnt/immunogenomics/RUNS/run183/',
#  '/mnt/immunogenomics/RUNS/run204/',
#  '/mnt/immunogenomics/RUNS/run211/',
#  '/mnt/immunogenomics/RUNS/run214/',
#  '/mnt/immunogenomics/RUNS/run217/',
#  '/mnt/immunogenomics/RUNS/run220/',
#  '/mnt/immunogenomics/RUNS/run222/',
#  '/mnt/immunogenomics/RUNS/run227/',
#  '/mnt/immunogenomics/RUNS/run234/',
#  '/mnt/immunogenomics/RUNS/run236/',
#  '/mnt/immunogenomics/RUNS/run239/',
#  '/mnt/immunogenomics/RUNS/run24/',
#  '/mnt/immunogenomics/RUNS/run241/',
#  '/mnt/immunogenomics/RUNS/run242/',
#  '/mnt/immunogenomics/RUNS/run243/',
#  '/mnt/immunogenomics/RUNS/run245/',
#  '/mnt/immunogenomics/RUNS/run246/',
#  '/mnt/immunogenomics/RUNS/run248/',
#  '/mnt/immunogenomics/RUNS/run251/',
#  '/mnt/immunogenomics/RUNS/run252/',
#  '/mnt/immunogenomics/RUNS/run254/',
#  '/mnt/immunogenomics/RUNS/run258/',
#  '/mnt/immunogenomics/RUNS/run259/',
#  '/mnt/immunogenomics/RUNS/run27/',
#  '/mnt/immunogenomics/RUNS/run34/',
#  '/mnt/immunogenomics/RUNS/run37/',
#  '/mnt/immunogenomics/RUNS/run41/',
#  '/mnt/immunogenomics/RUNS/run45/',
#  '/mnt/immunogenomics/RUNS/run49/',
#  '/mnt/immunogenomics/RUNS/run51/',
#  '/mnt/immunogenomics/RUNS/run55/',
#  '/mnt/immunogenomics/RUNS/run58/',
#  '/mnt/immunogenomics/RUNS/run61/',
#  '/mnt/immunogenomics/RUNS/run66/',
#  '/mnt/immunogenomics/RUNS/run70/',
#  '/mnt/immunogenomics/RUNS/run71/',
#  '/mnt/immunogenomics/RUNS/run73/',
#  '/mnt/immunogenomics/RUNS/run74/',
#  '/mnt/immunogenomics/RUNS/run81/',
#  '/mnt/immunogenomics/RUNS/run84/',
#  '/mnt/immunogenomics/RUNS/run88/',
#  '/mnt/immunogenomics/RUNS/run93/',
#  '/mnt/immunogenomics/RUNS/run98/']

# %%
# Is there a "data" subdirectory? If so, store it. If not, put it in another dictionary for manual check
data_dict = dict()
to_check_dict = dict()
for mydir in runlist:
    if "data" in os.listdir(mydir):
        data_dir = mydir + "data/"
        data_dict[data_dir] = os.listdir(data_dir)
    else:
        print("TO CHECK:", os.listdir(mydir))
        to_check_dict[mydir] = os.listdir(mydir)
# Out:
# TO CHECK: ['README.txt', 'results-tbcell']
# TO CHECK: ['results-tbcell']

# %%
# Need to download data from these directories manually
to_check_dict
# Out:
# {'/mnt/immunogenomics/RUNS/run214/': ['README.txt', 'results-tbcell'],
#  '/mnt/immunogenomics/RUNS/run258/': ['results-tbcell']}

# %% [markdown]
# ## List the fastq and sff files per run

# %%
# See if we can identify the right file(s) in the data directory (fastq.gz or .sff)
download_files = dict()
check_files = dict()
for data_dir, myfiles in data_dict.items():
    filelist = list()
    for myfile in myfiles:
        if myfile.endswith(".fastq.gz") or myfile.endswith(".sff"):
            filelist.append(myfile)
    if len(filelist) == 0:
        check_files[data_dir] = myfiles
    else:
        download_files[data_dir] = filelist

# %%
download_files
# Out:
# {'/mnt/immunogenomics/RUNS/run102/data/': ['HA06QXN01.sff', 'HA06QXN02.sff'],
#  '/mnt/immunogenomics/RUNS/run112/data/': ['HG10TD301.sff',
#   'HG10TD302.sff',
#   'run112-HG10TD301_S1_L001.assembled.fastq.gz',
#   'run112-HG10TD302_S1_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run114/data/': ['HHEXEGX01.sff',
#   'HHEXEGX02.sff',
#   'HHEXEGX03.sff',
#   'HHEXEGX04.sff'],
#  '/mnt/immunogenomics/RUNS/run122/data/': ['HI7M9GL01.sff',
#   'HI7M9GL02.sff',
#   'run122-r1-HI7M9GL01_S1_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run141/data/': ['HPV8MXM01.sff',
#   'HPV8MXM02.sff',
#   'run141-r1_L001.assembled.fastq.gz',
#   'run141-r2_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run142/data/': ['HPYCFHP01.sff',
#   'HPYCFHP02.sff',
#   'run142-r1_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run157/data/': ['HTS5G9E01.sff',
#   'HTS5G9E02.sff',
#   'run157-r1-1966994-T0-full_S20_L001.assembled.fastq.gz',
#   'run157-r1-5734848-T0-full_S18_L001.assembled.fastq.gz',
#   'run157-r1-5734848-T1-full_S23_L001.assembled.fastq.gz',
#   'run157-r1-7713715-T0-full_S17_L001.assembled.fastq.gz',
#   'run157-r1-7713715-T1-full_S22_L001.assembled.fastq.gz',
#   'run157-r1-G4030-Oxford-full_S21_L001.assembled.fastq.gz',
#   'run157-r1-G4066-Oxford-full_S19_L001.assembled.fastq.gz',
#   'run157-r1_L001.assembled.fastq.gz',
#   'run157-r2-1966994-T0-IgA_S24_L001.assembled.fastq.gz',
#   'run157-r2-1966994-T0-IgD_S32_L001.assembled.fastq.gz',
#   'run157-r2-1966994-T0-IgG_S28_L001.assembled.fastq.gz',
#   'run157-r2-1966994-T0-IgM_S1_L001.assembled.fastq.gz',
#   'run157-r2-5734848-T0-IgA_S9_L001.assembled.fastq.gz',
#   'run157-r2-5734848-T0-IgD_S16_L001.assembled.fastq.gz',
#   'run157-r2-5734848-T0-IgG_S12_L001.assembled.fastq.gz',
#   'run157-r2-5734848-T0-IgM_S25_L001.assembled.fastq.gz',
#   'run157-r2-5734848-T1-IgA_S2_L001.assembled.fastq.gz',
#   'run157-r2-5734848-T1-IgD_S4_L001.assembled.fastq.gz',
#   'run157-r2-5734848-T1-IgG_S39_L001.assembled.fastq.gz',
#   'run157-r2-5734848-T1-IgM_S38_L001.assembled.fastq.gz',
#   'run157-r2-7713715-T0-IgA_S3_L001.assembled.fastq.gz',
#   'run157-r2-7713715-T0-IgD_S6_L001.assembled.fastq.gz',
#   'run157-r2-7713715-T0-IgG_S5_L001.assembled.fastq.gz',
#   'run157-r2-7713715-T0-IgM_S31_L001.assembled.fastq.gz',
#   'run157-r2-7713715-T1-IgA_S26_L001.assembled.fastq.gz',
#   'run157-r2-7713715-T1-IgD_S35_L001.assembled.fastq.gz',
#   'run157-r2-7713715-T1-IgG_S34_L001.assembled.fastq.gz',
#   'run157-r2-7713715-T1-IgM_S7_L001.assembled.fastq.gz',
#   'run157-r2-G4010-IgA_S27_L001.assembled.fastq.gz',
#   'run157-r2-G4010-IgD_S30_L001.assembled.fastq.gz',
#   'run157-r2-G4010-IgG_S8_L001.assembled.fastq.gz',
#   'run157-r2-G4010-IgM_S36_L001.assembled.fastq.gz',
#   'run157-r2-G4030-IgA_S29_L001.assembled.fastq.gz',
#   'run157-r2-G4030-IgD_S14_L001.assembled.fastq.gz',
#   'run157-r2-G4030-IgG_S11_L001.assembled.fastq.gz',
#   'run157-r2-G4030-IgM_S33_L001.assembled.fastq.gz',
#   'run157-r2-G4066-IgA_S10_L001.assembled.fastq.gz',
#   'run157-r2-G4066-IgD_S13_L001.assembled.fastq.gz',
#   'run157-r2-G4066-IgG_S15_L001.assembled.fastq.gz',
#   'run157-r2-G4066-IgM_S37_L001.assembled.fastq.gz',
#   'run157-r2_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run160/data/': ['HU5IXOJ01.fastq.gz',
#   'HU5IXOJ01.sff',
#   'HU5IXOJ02.fastq.gz',
#   'HU5IXOJ02.sff',
#   'HU5IXOJ03.fastq.gz',
#   'HU5IXOJ03.sff',
#   'HU5IXOJ04.fastq.gz',
#   'HU5IXOJ04.sff'],
#  '/mnt/immunogenomics/RUNS/run162/data/': ['454Reads.BCRMID11.sff',
#   '454Reads.BCRMID12.sff',
#   '454Reads.BCRMID13.sff',
#   '454Reads.BCRMID14.sff',
#   '454Reads.BCRMID15.sff',
#   '454Reads.BCRMID16.sff',
#   '454Reads.BCRMID17.sff',
#   '454Reads.BCRMID18.sff',
#   '454Reads.BCRMID19.sff',
#   '454Reads.BCRMID2.sff',
#   '454Reads.BCRMID20.sff',
#   '454Reads.BCRMID22.sff',
#   '454Reads.BCRMID25.sff',
#   '454Reads.BCRMID27.sff',
#   '454Reads.BCRMID29.sff',
#   '454Reads.BCRMID3.sff',
#   '454Reads.BCRMID31.sff',
#   '454Reads.BCRMID32.sff',
#   '454Reads.BCRMID33.sff',
#   '454Reads.BCRMID35.sff',
#   '454Reads.BCRMID36.sff',
#   '454Reads.BCRMID37.sff',
#   '454Reads.BCRMID38.sff',
#   '454Reads.BCRMID8.sff',
#   '454Reads.BCRMID9.sff',
#   '454Reads.TCRAMID1.sff',
#   '454Reads.TCRAMID3.sff',
#   '454Reads.TCRBMID10.sff',
#   '454Reads.TCRBMID11.sff',
#   '454Reads.TCRBMID12.sff',
#   '454Reads.TCRBMID13.sff',
#   '454Reads.TCRBMID14.sff',
#   '454Reads.TCRBMID15.sff',
#   '454Reads.TCRBMID16.sff',
#   '454Reads.TCRBMID17.sff',
#   '454Reads.TCRBMID18.sff',
#   '454Reads.TCRBMID2.sff',
#   '454Reads.TCRBMID20.sff',
#   '454Reads.TCRBMID21.sff',
#   '454Reads.TCRBMID23.sff',
#   '454Reads.TCRBMID24.sff',
#   '454Reads.TCRBMID25.sff',
#   '454Reads.TCRBMID26.sff',
#   '454Reads.TCRBMID27.sff',
#   '454Reads.TCRBMID28.sff',
#   '454Reads.TCRBMID29.sff',
#   '454Reads.TCRBMID3.sff',
#   '454Reads.TCRBMID30.sff',
#   '454Reads.TCRBMID31.sff',
#   '454Reads.TCRBMID32.sff',
#   '454Reads.TCRBMID4.sff',
#   '454Reads.TCRBMID5.sff',
#   '454Reads.TCRBMID6.sff',
#   '454Reads.TCRBMID7.sff',
#   '454Reads.TCRBMID8.sff',
#   '454Reads.TCRBMID9.sff',
#   '454Reads.TCRMUSAMID1.sff',
#   '454Reads.TCRMUSAMID2.sff',
#   'HV4JT6A01.sff',
#   'HV4JT6A02.sff',
#   'run162-r2_L001.assembled-ACACTGCTCA.fastq.gz',
#   'run162-r2_L001.assembled-ACAGGGCTCA.fastq.gz',
#   'run162-r2_L001.assembled-ACATGAGCTC.fastq.gz',
#   'run162-r2_L001.assembled-ACTAGGGCTC.fastq.gz',
#   'run162-r2_L001.assembled-AGAACGGCTC.fastq.gz',
#   'run162-r2_L001.assembled-AGACGGCTCA.fastq.gz',
#   'run162-r2_L001.assembled-AGCTCAGCTC.fastq.gz',
#   'run162-r2_L001.assembled-AGTCAGCTCA.fastq.gz',
#   'run162-r2_L001.assembled-ATAACGCTCA.fastq.gz',
#   'run162-r2_L001.assembled-ATGAACGCTC.fastq.gz',
#   'run162-r2_L001.assembled-CCGAGGCTCA.fastq.gz',
#   'run162-r2_L001.assembled-CCTGAGGCTC.fastq.gz',
#   'run162-r2_L001.assembled-CGATCTGCTC.fastq.gz',
#   'run162-r2_L001.assembled-CGTCTGCTCA.fastq.gz',
#   'run162-r2_L001.assembled-CTCGACGCTC.fastq.gz',
#   'run162-r2_L001.assembled-CTGACGCTCA.fastq.gz',
#   'run162-r2_L001.assembled-CTGTAGGCTC.fastq.gz',
#   'run162-r2_L001.assembled-CTGTGAGCTC.fastq.gz',
#   'run162-r2_L001.assembled-CTTAGGCTCA.fastq.gz',
#   'run162-r2_L001.assembled-CTTGAGCTCA.fastq.gz',
#   'run162-r2_L001.assembled-TCGGAGCTCA.fastq.gz',
#   'run162-r2_L001.assembled-TCTGGAGCTC.fastq.gz',
#   'run162-r2_L001.assembled-TGACTGCTCA.fastq.gz',
#   'run162-r2_L001.assembled-TGCGACGCTC.fastq.gz',
#   'run162-r2_L001.assembled-TGCGCGGCTC.fastq.gz',
#   'run162-r2_L001.assembled-TGGACGCTCA.fastq.gz',
#   'run162-r2_L001.assembled-TGGCGGCTCA.fastq.gz',
#   'run162-r2_L001.assembled-TTAGTGCTCA.fastq.gz',
#   'run162-r2_L001.assembled-TTGAGTGCTC.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run169/data/': ['HY135GI01.sff',
#   'HY135GI02.sff',
#   'run169-r1_L001.assembled.fastq.gz',
#   'run169-r2_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run181/data/': ['H33CZSB01.sff',
#   'H33CZSB02.sff',
#   'run181-r1_L001.assembled.fastq.gz',
#   'run181-r2_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run183/data/': ['H4W1I3K01.sff', 'H4W1I3K02.sff'],
#  '/mnt/immunogenomics/RUNS/run204/data/': ['IA8V3GT01.sff',
#   'IA8V3GT02.sff',
#   'run204-r1-0582743-t0-IgA_S12_L001.assembled.fastq.gz',
#   'run204-r1-0582743-t0-IgD_S14_L001.assembled.fastq.gz',
#   'run204-r1-0582743-t0-IgG_S13_L001.assembled.fastq.gz',
#   'run204-r1-0582743-t0-IgM_S11_L001.assembled.fastq.gz',
#   'run204-r1-2280816-t0-IgA_S20_L001.assembled.fastq.gz',
#   'run204-r1-2280816-t0-IgD_S22_L001.assembled.fastq.gz',
#   'run204-r1-2280816-t0-IgG_S21_L001.assembled.fastq.gz',
#   'run204-r1-2280816-t0-IgM_S19_L001.assembled.fastq.gz',
#   'run204-r1-3399763-t0-IgA_S28_L001.assembled.fastq.gz',
#   'run204-r1-3399763-t0-IgD_S30_L001.assembled.fastq.gz',
#   'run204-r1-3399763-t0-IgG_S29_L001.assembled.fastq.gz',
#   'run204-r1-3399763-t0-IgM_S27_L001.assembled.fastq.gz',
#   'run204-r1-3761347-t0-IgA_S24_L001.assembled.fastq.gz',
#   'run204-r1-3761347-t0-IgD_S26_L001.assembled.fastq.gz',
#   'run204-r1-3761347-t0-IgG_S25_L001.assembled.fastq.gz',
#   'run204-r1-3761347-t0-IgM_S23_L001.assembled.fastq.gz',
#   'run204-r1-9772319-t0-IgA_S16_L001.assembled.fastq.gz',
#   'run204-r1-9772319-t0-IgD_S18_L001.assembled.fastq.gz',
#   'run204-r1-9772319-t0-IgG_S17_L001.assembled.fastq.gz',
#   'run204-r1-9772319-t0-IgM_S15_L001.assembled.fastq.gz',
#   'run204-r1-9781109-t0-IgA_S8_L001.assembled.fastq.gz',
#   'run204-r1-9781109-t0-IgD_S10_L001.assembled.fastq.gz',
#   'run204-r1-9781109-t0-IgG_S9_L001.assembled.fastq.gz',
#   'run204-r1-9781109-t0-IgM_S7_L001.assembled.fastq.gz',
#   'run204-r1-IA8V3GT01_S1_L001.assembled.fastq.gz',
#   'run204-r2-0582743-t0-full_S2_L001.assembled.fastq.gz',
#   'run204-r2-2280816-t0-full_S6_L001.assembled.fastq.gz',
#   'run204-r2-3399763-t0-full_S3_L001.assembled.fastq.gz',
#   'run204-r2-3761347-t0-full_S1_L001.assembled.fastq.gz',
#   'run204-r2-9772319-t0-full_S5_L001.assembled.fastq.gz',
#   'run204-r2-9781109-t0-full_S4_L001.assembled.fastq.gz',
#   'run204-r2-IA8V3GT02_S2_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run211/data/': ['IC7F61C01.sff',
#   'IC7F61C02.sff',
#   'IC7F61C02.sff.fna.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run217/data/': ['IG36VCC01.sff',
#   'IG36VCC01.sff.fna.fastq.gz',
#   'IG36VCC02.sff',
#   'IG36VCC02.sff.fna.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run220/data/': ['IJOGYJG01-sig20131122.sff',
#   'IJOGYJG02-sig20131121.sff',
#   'run220-r1_L001.assembled.fastq.gz',
#   'run220-r2_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run222/data/': ['IKPLROJ02.sff',
#   'run222-r2_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run227/data/': ['IOC5O8H02.fastq.gz',
#   'IOC5O8H02.sff'],
#  '/mnt/immunogenomics/RUNS/run234/data/': ['IQGX1OJ01.sff',
#   'IQGX1OJ02.sff',
#   'run234-r1-0803324-T0-full_S15_L001.assembled.fastq.gz',
#   'run234-r1-1733880-T0-full_S11_L001.assembled.fastq.gz',
#   'run234-r1-1754508-t0-IgA_S31_L001.assembled.fastq.gz',
#   'run234-r1-1754508-t0-IgD_S2_L001.assembled.fastq.gz',
#   'run234-r1-1754508-t0-IgG_S28_L001.assembled.fastq.gz',
#   'run234-r1-1754508-t0-IgM_S32_L001.assembled.fastq.gz',
#   'run234-r1-1754508-t0-full_S17_L001.assembled.fastq.gz',
#   'run234-r1-1781711-t0-full_S25_L001.assembled.fastq.gz',
#   'run234-r1-2286298-T0-full_S22_L001.assembled.fastq.gz',
#   'run234-r1-2618641-T0-full_S29_L001.assembled.fastq.gz',
#   'run234-r1-4830499-T0-full_S7_L001.assembled.fastq.gz',
#   'run234-r1-5811158-T0-full_S26_L001.assembled.fastq.gz',
#   'run234-r1-6415038-t0-IgA_S14_L001.assembled.fastq.gz',
#   'run234-r1-6415038-t0-IgD_S4_L001.assembled.fastq.gz',
#   'run234-r1-6415038-t0-IgG_S16_L001.assembled.fastq.gz',
#   'run234-r1-6415038-t0-IgM_S30_L001.assembled.fastq.gz',
#   'run234-r1-6415038-t0-full_S19_L001.assembled.fastq.gz',
#   'run234-r1-7788769-t0-IgA_S12_L001.assembled.fastq.gz',
#   'run234-r1-7788769-t0-IgD_S5_L001.assembled.fastq.gz',
#   'run234-r1-7788769-t0-IgG_S1_L001.assembled.fastq.gz',
#   'run234-r1-7788769-t0-IgM_S6_L001.assembled.fastq.gz',
#   'run234-r1-7788769-t0-full_S10_L001.assembled.fastq.gz',
#   'run234-r1-7788976-Papilla-full_S27_L001.assembled.fastq.gz',
#   'run234-r1-G4001-full_S9_L001.assembled.fastq.gz',
#   'run234-r1-G4019-full_S20_L001.assembled.fastq.gz',
#   'run234-r1-G4036-full_S23_L001.assembled.fastq.gz',
#   'run234-r1-G4053-full_S3_L001.assembled.fastq.gz',
#   'run234-r1-G4072-full_S8_L001.assembled.fastq.gz',
#   'run234-r1-G4081-full_S13_L001.assembled.fastq.gz',
#   'run234-r1-G4086-full_S21_L001.assembled.fastq.gz',
#   'run234-r1-G4091-full_S18_L001.assembled.fastq.gz',
#   'run234-r1-G4145-full_S24_L001.assembled.fastq.gz',
#   'run234-r1_L001.assembled.fastq.gz',
#   'run234-r2_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run236/data/': ['IRU58BZ01.sff',
#   'IRU58BZ02.sff',
#   'IRU58BZ03.sff',
#   'IRU58BZ04.sff',
#   'run236-r1_L001.assembled.fastq.gz',
#   'run236-r2-1733880-t0-IgA_S1_L001.assembled.fastq.gz',
#   'run236-r2-1733880-t0-IgD_S3_L001.assembled.fastq.gz',
#   'run236-r2-1733880-t0-IgG_S14_L001.assembled.fastq.gz',
#   'run236-r2-1733880-t0-IgM_S2_L001.assembled.fastq.gz',
#   'run236-r2-1781711-t0-IgA_S16_L001.assembled.fastq.gz',
#   'run236-r2-1781711-t0-IgD_S5_L001.assembled.fastq.gz',
#   'run236-r2-1781711-t0-IgG_S4_L001.assembled.fastq.gz',
#   'run236-r2-1781711-t0-IgM_S23_L001.assembled.fastq.gz',
#   'run236-r2-2286298-t0-IgA_S18_L001.assembled.fastq.gz',
#   'run236-r2-2286298-t0-IgD_S20_L001.assembled.fastq.gz',
#   'run236-r2-2286298-t0-IgG_S12_L001.assembled.fastq.gz',
#   'run236-r2-2286298-t0-IgM_S13_L001.assembled.fastq.gz',
#   'run236-r2-2618641-t0-IgA_S17_L001.assembled.fastq.gz',
#   'run236-r2-2618641-t0-IgD_S21_L001.assembled.fastq.gz',
#   'run236-r2-2618641-t0-IgG_S6_L001.assembled.fastq.gz',
#   'run236-r2-2618641-t0-IgM_S7_L001.assembled.fastq.gz',
#   'run236-r2-4830499-t0-IgA_S11_L001.assembled.fastq.gz',
#   'run236-r2-4830499-t0-IgD_S22_L001.assembled.fastq.gz',
#   'run236-r2-4830499-t0-IgG_S15_L001.assembled.fastq.gz',
#   'run236-r2-4830499-t0-IgM_S19_L001.assembled.fastq.gz',
#   'run236-r2_L001.assembled.fastq.gz',
#   'run236-r3-0803324-t0-IgA_S8_L001.assembled.fastq.gz',
#   'run236-r3-0803324-t0-IgD_S61_L001.assembled.fastq.gz',
#   'run236-r3-0803324-t0-IgG_S10_L001.assembled.fastq.gz',
#   'run236-r3-0803324-t0-IgM_S63_L001.assembled.fastq.gz',
#   'run236-r3-5811158-t0-IgA_S40_L001.assembled.fastq.gz',
#   'run236-r3-5811158-t0-IgD_S31_L001.assembled.fastq.gz',
#   'run236-r3-5811158-t0-IgG_S28_L001.assembled.fastq.gz',
#   'run236-r3-5811158-t0-IgM_S62_L001.assembled.fastq.gz',
#   'run236-r3-7788976-papilla-IgA_S34_L001.assembled.fastq.gz',
#   'run236-r3-7788976-papilla-IgD_S68_L001.assembled.fastq.gz',
#   'run236-r3-7788976-papilla-IgG_S47_L001.assembled.fastq.gz',
#   'run236-r3-7788976-papilla-IgM_S59_L001.assembled.fastq.gz',
#   'run236-r3-G4001-IgA_S25_L001.assembled.fastq.gz',
#   'run236-r3-G4001-IgD_S41_L001.assembled.fastq.gz',
#   'run236-r3-G4001-IgG_S45_L001.assembled.fastq.gz',
#   'run236-r3-G4001-IgM_S60_L001.assembled.fastq.gz',
#   'run236-r3-G4019-IgA_S39_L001.assembled.fastq.gz',
#   'run236-r3-G4019-IgD_S49_L001.assembled.fastq.gz',
#   'run236-r3-G4019-IgG_S38_L001.assembled.fastq.gz',
#   'run236-r3-G4019-IgM_S66_L001.assembled.fastq.gz',
#   'run236-r3-G4036-IgA_S24_L001.assembled.fastq.gz',
#   'run236-r3-G4036-IgD_S43_L001.assembled.fastq.gz',
#   'run236-r3-G4036-IgG_S9_L001.assembled.fastq.gz',
#   'run236-r3-G4036-IgM_S26_L001.assembled.fastq.gz',
#   'run236-r3-G4053-IgA_S48_L001.assembled.fastq.gz',
#   'run236-r3-G4053-IgD_S33_L001.assembled.fastq.gz',
#   'run236-r3-G4053-IgG_S37_L001.assembled.fastq.gz',
#   'run236-r3-G4053-IgM_S55_L001.assembled.fastq.gz',
#   'run236-r3-G4072-IgA_S42_L001.assembled.fastq.gz',
#   'run236-r3-G4072-IgD_S53_L001.assembled.fastq.gz',
#   'run236-r3-G4072-IgG_S52_L001.assembled.fastq.gz',
#   'run236-r3-G4072-IgM_S56_L001.assembled.fastq.gz',
#   'run236-r3-G4081-IgA_S64_L001.assembled.fastq.gz',
#   'run236-r3-G4081-IgD_S50_L001.assembled.fastq.gz',
#   'run236-r3-G4081-IgG_S27_L001.assembled.fastq.gz',
#   'run236-r3-G4081-IgM_S65_L001.assembled.fastq.gz',
#   'run236-r3-G4086-IgA_S57_L001.assembled.fastq.gz',
#   'run236-r3-G4086-IgD_S30_L001.assembled.fastq.gz',
#   'run236-r3-G4086-IgG_S44_L001.assembled.fastq.gz',
#   'run236-r3-G4086-IgM_S58_L001.assembled.fastq.gz',
#   'run236-r3-G4091-IgA_S32_L001.assembled.fastq.gz',
#   'run236-r3-G4091-IgD_S36_L001.assembled.fastq.gz',
#   'run236-r3-G4091-IgG_S54_L001.assembled.fastq.gz',
#   'run236-r3-G4091-IgM_S51_L001.assembled.fastq.gz',
#   'run236-r3-G4145-IgA_S67_L001.assembled.fastq.gz',
#   'run236-r3-G4145-IgD_S29_L001.assembled.fastq.gz',
#   'run236-r3-G4145-IgG_S35_L001.assembled.fastq.gz',
#   'run236-r3-G4145-IgM_S46_L001.assembled.fastq.gz',
#   'run236-r3_L001.assembled.fastq.gz',
#   'run236-r4_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run239/data/': ['ITW40QN01.sff',
#   'ITW40QN02.sff',
#   'ITW40QN02.sff.fna.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run24/data/': ['FVUGYZ001.sff',
#   'FVUGYZ002.sff',
#   'FVUGYZ003.sff',
#   'FVUGYZ004.sff'],
#  '/mnt/immunogenomics/RUNS/run241/data/': ['IWAB1T402.sff'],
#  '/mnt/immunogenomics/RUNS/run242/data/': ['IXKJMGP01.sff',
#   'IXKJMGP02.sff',
#   'run242-r2-1754508-T8_S1_L001.assembled.fastq.gz',
#   'run242-r2-9781109-t4_S2_L001.assembled.fastq.gz',
#   'run242-r2-IXKJMGP02_S2_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run243/data/': ['I0EK49M01.sff', 'I0EK49M02.sff'],
#  '/mnt/immunogenomics/RUNS/run245/data/': ['I2TDHKF01.sff',
#   'I2TDHKF02.sff',
#   'run245-r1-I2TDHKF01_S1_L001.assembled.fastq.gz',
#   'run245-r2-G4088-IgA_S31_L001.assembled.fastq.gz',
#   'run245-r2-G4088-IgD_S35_L001.assembled.fastq.gz',
#   'run245-r2-G4088-IgG_S45_L001.assembled.fastq.gz',
#   'run245-r2-G4088-IgM_S27_L001.assembled.fastq.gz',
#   'run245-r2-G4088-full_S8_L001.assembled.fastq.gz',
#   'run245-r2-G4106-IgA_S24_L001.assembled.fastq.gz',
#   'run245-r2-G4106-IgD_S34_L001.assembled.fastq.gz',
#   'run245-r2-G4106-IgG_S44_L001.assembled.fastq.gz',
#   'run245-r2-G4106-IgM_S16_L001.assembled.fastq.gz',
#   'run245-r2-G4106-full_S32_L001.assembled.fastq.gz',
#   'run245-r2-G4109-IgA_S5_L001.assembled.fastq.gz',
#   'run245-r2-G4109-IgD_S25_L001.assembled.fastq.gz',
#   'run245-r2-G4109-IgG_S23_L001.assembled.fastq.gz',
#   'run245-r2-G4109-IgM_S56_L001.assembled.fastq.gz',
#   'run245-r2-G4109-full_S30_L001.assembled.fastq.gz',
#   'run245-r2-G4110-IgA_S26_L001.assembled.fastq.gz',
#   'run245-r2-G4110-IgD_S43_L001.assembled.fastq.gz',
#   'run245-r2-G4110-IgG_S54_L001.assembled.fastq.gz',
#   'run245-r2-G4110-IgM_S57_L001.assembled.fastq.gz',
#   'run245-r2-G4110-full_S11_L001.assembled.fastq.gz',
#   'run245-r2-G4143-IgA_S37_L001.assembled.fastq.gz',
#   'run245-r2-G4143-IgD_S3_L001.assembled.fastq.gz',
#   'run245-r2-G4143-IgG_S29_L001.assembled.fastq.gz',
#   'run245-r2-G4143-IgM_S58_L001.assembled.fastq.gz',
#   'run245-r2-G4143-full_S12_L001.assembled.fastq.gz',
#   'run245-r2-G4150-IgA_S40_L001.assembled.fastq.gz',
#   'run245-r2-G4150-IgD_S39_L001.assembled.fastq.gz',
#   'run245-r2-G4150-IgG_S49_L001.assembled.fastq.gz',
#   'run245-r2-G4150-IgM_S52_L001.assembled.fastq.gz',
#   'run245-r2-G4150-full_S21_L001.assembled.fastq.gz',
#   'run245-r2-G4151-IgA_S15_L001.assembled.fastq.gz',
#   'run245-r2-G4151-IgD_S46_L001.assembled.fastq.gz',
#   'run245-r2-G4151-IgG_S2_L001.assembled.fastq.gz',
#   'run245-r2-G4151-IgM_S59_L001.assembled.fastq.gz',
#   'run245-r2-G4151-full_S4_L001.assembled.fastq.gz',
#   'run245-r2-G4157-IgA_S19_L001.assembled.fastq.gz',
#   'run245-r2-G4157-IgD_S36_L001.assembled.fastq.gz',
#   'run245-r2-G4157-IgG_S10_L001.assembled.fastq.gz',
#   'run245-r2-G4157-IgM_S33_L001.assembled.fastq.gz',
#   'run245-r2-G4157-full_S18_L001.assembled.fastq.gz',
#   'run245-r2-G4169-IgA_S9_L001.assembled.fastq.gz',
#   'run245-r2-G4169-IgD_S7_L001.assembled.fastq.gz',
#   'run245-r2-G4169-IgG_S13_L001.assembled.fastq.gz',
#   'run245-r2-G4169-IgM_S6_L001.assembled.fastq.gz',
#   'run245-r2-G4169-full_S17_L001.assembled.fastq.gz',
#   'run245-r2-G4170-IgA_S22_L001.assembled.fastq.gz',
#   'run245-r2-G4170-IgD_S41_L001.assembled.fastq.gz',
#   'run245-r2-G4170-IgG_S50_L001.assembled.fastq.gz',
#   'run245-r2-G4170-IgM_S47_L001.assembled.fastq.gz',
#   'run245-r2-G4170-full_S28_L001.assembled.fastq.gz',
#   'run245-r2-G4176-IgA_S60_L001.assembled.fastq.gz',
#   'run245-r2-G4176-IgD_S42_L001.assembled.fastq.gz',
#   'run245-r2-G4176-IgG_S38_L001.assembled.fastq.gz',
#   'run245-r2-G4176-IgM_S55_L001.assembled.fastq.gz',
#   'run245-r2-G4176-full_S1_L001.assembled.fastq.gz',
#   'run245-r2-G4178-IgA_S20_L001.assembled.fastq.gz',
#   'run245-r2-G4178-IgD_S48_L001.assembled.fastq.gz',
#   'run245-r2-G4178-IgG_S53_L001.assembled.fastq.gz',
#   'run245-r2-G4178-IgM_S51_L001.assembled.fastq.gz',
#   'run245-r2-G4178-full_S14_L001.assembled.fastq.gz',
#   'run245-r2-I2TDHKF02_S2_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run246/data/': ['I4IMECA01.sff',
#   'I4IMECA01.sff.fastq.gz',
#   'I4IMECA02.sff'],
#  '/mnt/immunogenomics/RUNS/run248/data/': ['I9PJZJP01.sff',
#   'I9PJZJP02.sff',
#   'run248-r1-0855233-t0-full_S22_L001.assembled.fastq.gz',
#   'run248-r1-1774224-t0-IgA_S28_L001.assembled.fastq.gz',
#   'run248-r1-1774224-t0-IgD_S30_L001.assembled.fastq.gz',
#   'run248-r1-1774224-t0-IgG_S41_L001.assembled.fastq.gz',
#   'run248-r1-1774224-t0-IgM_S36_L001.assembled.fastq.gz',
#   'run248-r1-1774224-t0-full_S19_L001.assembled.fastq.gz',
#   'run248-r1-1831058-t0-IgA_S26_L001.assembled.fastq.gz',
#   'run248-r1-1831058-t0-IgD_S20_L001.assembled.fastq.gz',
#   'run248-r1-1831058-t0-IgG_S39_L001.assembled.fastq.gz',
#   'run248-r1-1831058-t0-IgM_S2_L001.assembled.fastq.gz',
#   'run248-r1-1831058-t0-full_S100_L001.assembled.fastq.gz',
#   'run248-r1-3658045-t0-IgA_S9_L001.assembled.fastq.gz',
#   'run248-r1-3658045-t0-IgD_S33_L001.assembled.fastq.gz',
#   'run248-r1-3658045-t0-IgG_S3_L001.assembled.fastq.gz',
#   'run248-r1-3658045-t0-IgM_S42_L001.assembled.fastq.gz',
#   'run248-r1-3658045-t0-full_S31_L001.assembled.fastq.gz',
#   'run248-r1-4830608-t0-IgA_S10_L001.assembled.fastq.gz',
#   'run248-r1-4830608-t0-IgD_S4_L001.assembled.fastq.gz',
#   'run248-r1-4830608-t0-IgG_S27_L001.assembled.fastq.gz',
#   'run248-r1-4830608-t0-IgM_S11_L001.assembled.fastq.gz',
#   'run248-r1-4852247-t0-full_S25_L001.assembled.fastq.gz',
#   'run248-r1-5847500-t0-IgA_S21_L001.assembled.fastq.gz',
#   'run248-r1-5847500-t0-IgD_S7_L001.assembled.fastq.gz',
#   'run248-r1-5847500-t0-IgG_S5_L001.assembled.fastq.gz',
#   'run248-r1-5847500-t0-IgM_S40_L001.assembled.fastq.gz',
#   'run248-r1-5847500-t0-full_S23_L001.assembled.fastq.gz',
#   'run248-r1-7836191-t0-IgA_S29_L001.assembled.fastq.gz',
#   'run248-r1-7836191-t0-IgD_S8_L001.assembled.fastq.gz',
#   'run248-r1-7836191-t0-IgG_S34_L001.assembled.fastq.gz',
#   'run248-r1-7836191-t0-IgM_S6_L001.assembled.fastq.gz',
#   'run248-r1-7836191-t0-full_S24_L001.assembled.fastq.gz',
#   'run248-r1-7836656-t0-IgA_S18_L001.assembled.fastq.gz',
#   'run248-r1-7836656-t0-IgD_S38_L001.assembled.fastq.gz',
#   'run248-r1-7836656-t0-IgG_S35_L001.assembled.fastq.gz',
#   'run248-r1-7836656-t0-IgM_S43_L001.assembled.fastq.gz',
#   'run248-r1-7836656-t0-full_S32_L001.assembled.fastq.gz',
#   'run248-r1-8832497-t0-full_S37_L001.assembled.fastq.gz',
#   'run248-r1-8854978-t0-full_S1_L001.assembled.fastq.gz',
#   'run248-r1_L001.assembled.fastq.gz',
#   'run248-r2-0855233-t0-IgA_S13_L001.assembled.fastq.gz',
#   'run248-r2-0855233-t0-IgD_S58_L001.assembled.fastq.gz',
#   'run248-r2-0855233-t0-IgG_S63_L001.assembled.fastq.gz',
#   'run248-r2-0855233-t0-IgM_S62_L001.assembled.fastq.gz',
#   'run248-r2-2667712-t0-IgA_S14_L001.assembled.fastq.gz',
#   'run248-r2-2667712-t0-IgD_S55_L001.assembled.fastq.gz',
#   'run248-r2-2667712-t0-IgG_S59_L001.assembled.fastq.gz',
#   'run248-r2-2667712-t0-IgM_S64_L001.assembled.fastq.gz',
#   'run248-r2-4829042-t0-IgA_S49_L001.assembled.fastq.gz',
#   'run248-r2-4829042-t0-IgD_S57_L001.assembled.fastq.gz',
#   'run248-r2-4829042-t0-IgG_S15_L001.assembled.fastq.gz',
#   'run248-r2-4829042-t0-IgM_S48_L001.assembled.fastq.gz',
#   'run248-r2-4852247-t0-IgA_S45_L001.assembled.fastq.gz',
#   'run248-r2-4852247-t0-IgD_S65_L001.assembled.fastq.gz',
#   'run248-r2-4852247-t0-IgG_S47_L001.assembled.fastq.gz',
#   'run248-r2-4852247-t0-IgM_S52_L001.assembled.fastq.gz',
#   'run248-r2-6833080-t0-IgA_S60_L001.assembled.fastq.gz',
#   'run248-r2-6833080-t0-IgD_S56_L001.assembled.fastq.gz',
#   'run248-r2-6833080-t0-IgG_S51_L001.assembled.fastq.gz',
#   'run248-r2-6833080-t0-IgM_S50_L001.assembled.fastq.gz',
#   'run248-r2-8832497-t0-IgA_S17_L001.assembled.fastq.gz',
#   'run248-r2-8832497-t0-IgD_S46_L001.assembled.fastq.gz',
#   'run248-r2-8832497-t0-IgG_S16_L001.assembled.fastq.gz',
#   'run248-r2-8832497-t0-IgM_S54_L001.assembled.fastq.gz',
#   'run248-r2-8854978-t0-IgA_S44_L001.assembled.fastq.gz',
#   'run248-r2-8854978-t0-IgD_S61_L001.assembled.fastq.gz',
#   'run248-r2-8854978-t0-IgG_S12_L001.assembled.fastq.gz',
#   'run248-r2-8854978-t0-IgM_S53_L001.assembled.fastq.gz',
#   'run248-r2_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run251/data/': ['JDG3JVM01.sff',
#   'JDG3JVM02.sff',
#   'run251-r1-4830608-t0-full_S5_L001.assembled.fastq.gz',
#   'run251-r1-4852247-t0-IgA_S1_L001.assembled.fastq.gz',
#   'run251-r1-4852247-t0-IgD_S3_L001.assembled.fastq.gz',
#   'run251-r1-4852247-t0-IgG_S4_L001.assembled.fastq.gz',
#   'run251-r1-4852247-t0-IgM_S6_L001.assembled.fastq.gz',
#   'run251-r1-4852247-t0-full_S2_L001.assembled.fastq.gz',
#   'run251-r1_L001.assembled.fastq.gz',
#   'run251-r2-4830608-t0-full_S7_L001.assembled.fastq.gz',
#   'run251-r2-4852247-t0-full_S8_L001.assembled.fastq.gz',
#   'run251-r2_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run252/data/': ['JFBFA9N01.sff',
#   'JFBFA9N02.sff',
#   'run252-r1-JFBFA9N01_S1_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run254/data/': ['JI6EKIL01.sff', 'JI6EKIL02.sff'],
#  '/mnt/immunogenomics/RUNS/run259/data/': ['JV3AIYM01.sff',
#   'JV3AIYM02.sff',
#   'run259-r1-JV3AIYM01_S1_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run27/data/': ['F3EL0MZ01.sff'],
#  '/mnt/immunogenomics/RUNS/run34/data/': ['F6SXVTI01.sff', 'F6SXVTI02.sff'],
#  '/mnt/immunogenomics/RUNS/run37/data/': ['GAIEXSY01.sff',
#   'GAIEXSY02.sff',
#   'GAIEXSY03.sff',
#   'GAIEXSY04.sff'],
#  '/mnt/immunogenomics/RUNS/run41/data/': ['GB5HR3001.sff',
#   'GB5HR3002.sff',
#   'GB5HR3003.sff',
#   'GB5HR3004.sff'],
#  '/mnt/immunogenomics/RUNS/run45/data/': ['GFAGD2L01.sff', 'GFAGD2L02.sff'],
#  '/mnt/immunogenomics/RUNS/run49/data/': ['GHW6GYB01.sff', 'GHW6GYB02.sff'],
#  '/mnt/immunogenomics/RUNS/run51/data/': ['GI3GR6H01.sff', 'GI3GR6H02.sff'],
#  '/mnt/immunogenomics/RUNS/run55/data/': ['GK7M7SC01.sff',
#   'GK7M7SC02.sff',
#   'GK7M7SC03.sff',
#   'GK7M7SC04.sff',
#   'GK7M7SC05.sff'],
#  '/mnt/immunogenomics/RUNS/run58/data/': ['GMUTUER01.sff', 'GMUTUER02.sff'],
#  '/mnt/immunogenomics/RUNS/run61/data/': ['GPR83OS01.sff',
#   'GPR83OS02.sff',
#   'GPR83OS03.sff',
#   'GPR83OS04.sff',
#   'GPR83OS05.sff',
#   'run61-r2-GPR83OS02_S2_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run66/data/': ['GQY2LBU01.sff',
#   'GQY2LBU02.sff',
#   'run66-r1-GQY2LBU01_S1_L001.assembled.fastq.gz',
#   'run66-r2-GQY2LBU02_S2_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run70/data/': ['GS96CJ301.sff',
#   'GS96CJ302.sff',
#   'run70-r2-GS96CJ302_S2_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run71/data/': ['GVHSAYA01.sff',
#   'GVHSAYA02.sff',
#   'run71-r1-GVHSAYA01_S1_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run73/data/': ['GWBG4B301.sff',
#   'GWBG4B302.sff',
#   'run73-r1-GWBG4B301_S1_L001.assembled.fastq.gz',
#   'run73-r2-GWBG4B302_S2_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run74/data/': ['GWXOY9L01.sff',
#   'GWXOY9L02.sff',
#   'run74-r1_L001.assembled.fastq.gz',
#   'run74-r2_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run81/data/': ['G0JF89301.sff',
#   'G0JF89302.sff',
#   'run81-r1_L001.assembled.fastq.gz',
#   'run81-r2_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run84/data/': ['G2WRF6E01.sff',
#   'G2WRF6E02.sff',
#   'run84-r1-G2WRF6E01_S1_L001.assembled.fastq.gz',
#   'run84-r2-G2WRF6E02_S2_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run88/data/': ['G3BFJQD01.sff',
#   'G3BFJQD02.sff',
#   'run88-r1-G3BFJQD01_S3_L001.assembled.fastq.gz',
#   'run88-r2-G3BFJQD02_S4_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run93/data/': ['G62R2TI01.sff',
#   'G62R2TI02.sff',
#   'run93-r1-G62R2TI01_S1_L001.assembled.fastq.gz',
#   'run93-r2-G62R2TI02_S2_L001.assembled.fastq.gz'],
#  '/mnt/immunogenomics/RUNS/run98/data/': ['G9UO0YJ01.sff',
#   'G9UO0YJ01_L001.assembled.fastq.gz',
#   'G9UO0YJ02.sff',
#   'G9UO0YJ02_L001.assembled.fastq.gz']}

# %%
# Do all data directories contain fastq and/or sff files? If so, this dict should be empty
check_files
# Out:
# {}

# %% [markdown]
# ## Notes
# I checked the list above manually to see which sff files were already converted to fastq and which are not. I'm going to make two separate lists for this below.

# %%
convert_sff = ['run102','run114','run122','run162','run183','run211','run239','run24',
               'run241','run242','run243','run246','run252','run254','run259','run27',
               'run34','run37','run41','run45','run49','run51','run55','run58','run61',
               'run70','run71']
already_converted = ['run112','run141','run157','run160','run169','run181',
                     'run204','run217','run220','run222','run227','run234','run236',
                     'run245','run248','run251','run66','run73','run74','run81',
                     'run84','run88','run93','run98']
run142_fastqdir = "/mnt/immunogenomics/RUNS/run142/" # note that the correct fastq files for this run is not in data subdir!

# %%
f = lambda x: "/mnt/immunogenomics/RUNS/" + x + "/data/"
convert_sff = [x for x in map(f, convert_sff)]
already_converted = [x for x in map(f, already_converted)]

# %%
# Add the fastq files of run142
[x for x in os.listdir(run142_fastqdir) if x.endswith(".fastq.gz")]
# Out:
# ['run142-r1_L001.assembled.fastq.gz', 'run142-r2_L001.assembled.fastq.gz']

# %% [markdown]
# ## Create dictionaries for sff files and for fastq files

# %%
download_sff = dict()
download_fastq = dict()
for mydir in convert_sff:
    myfiles = [x for x in download_files.get(mydir) if x.endswith(".sff")]
    myfiles = [x for x in myfiles if not x.startswith("454Reads")]
    download_sff[mydir] = myfiles
download_fastq = dict()
for mydir in already_converted:
    myfiles = [x for x in download_files.get(mydir) if x.endswith(".fastq.gz")]
    download_fastq[mydir] = myfiles

# %%
download_sff
# Out:
# {'/mnt/immunogenomics/RUNS/run102/data/': ['HA06QXN01.sff', 'HA06QXN02.sff'],
#  '/mnt/immunogenomics/RUNS/run114/data/': ['HHEXEGX01.sff',
#   'HHEXEGX02.sff',
#   'HHEXEGX03.sff',
#   'HHEXEGX04.sff'],
#  '/mnt/immunogenomics/RUNS/run122/data/': ['HI7M9GL01.sff', 'HI7M9GL02.sff'],
#  '/mnt/immunogenomics/RUNS/run162/data/': ['HV4JT6A01.sff', 'HV4JT6A02.sff'],
#  '/mnt/immunogenomics/RUNS/run183/data/': ['H4W1I3K01.sff', 'H4W1I3K02.sff'],
#  '/mnt/immunogenomics/RUNS/run211/data/': ['IC7F61C01.sff', 'IC7F61C02.sff'],
#  '/mnt/immunogenomics/RUNS/run239/data/': ['ITW40QN01.sff', 'ITW40QN02.sff'],
#  '/mnt/immunogenomics/RUNS/run24/data/': ['FVUGYZ001.sff',
#   'FVUGYZ002.sff',
#   'FVUGYZ003.sff',
#   'FVUGYZ004.sff'],
#  '/mnt/immunogenomics/RUNS/run241/data/': ['IWAB1T402.sff'],
#  '/mnt/immunogenomics/RUNS/run242/data/': ['IXKJMGP01.sff', 'IXKJMGP02.sff'],
#  '/mnt/immunogenomics/RUNS/run243/data/': ['I0EK49M01.sff', 'I0EK49M02.sff'],
#  '/mnt/immunogenomics/RUNS/run246/data/': ['I4IMECA01.sff', 'I4IMECA02.sff'],
#  '/mnt/immunogenomics/RUNS/run252/data/': ['JFBFA9N01.sff', 'JFBFA9N02.sff'],
#  '/mnt/immunogenomics/RUNS/run254/data/': ['JI6EKIL01.sff', 'JI6EKIL02.sff'],
#  '/mnt/immunogenomics/RUNS/run259/data/': ['JV3AIYM01.sff', 'JV3AIYM02.sff'],
#  '/mnt/immunogenomics/RUNS/run27/data/': ['F3EL0MZ01.sff'],
#  '/mnt/immunogenomics/RUNS/run34/data/': ['F6SXVTI01.sff', 'F6SXVTI02.sff'],
#  '/mnt/immunogenomics/RUNS/run37/data/': ['GAIEXSY01.sff',
#   'GAIEXSY02.sff',
#   'GAIEXSY03.sff',
#   'GAIEXSY04.sff'],
#  '/mnt/immunogenomics/RUNS/run41/data/': ['GB5HR3001.sff',
#   'GB5HR3002.sff',
#   'GB5HR3003.sff',
#   'GB5HR3004.sff'],
#  '/mnt/immunogenomics/RUNS/run45/data/': ['GFAGD2L01.sff', 'GFAGD2L02.sff'],
#  '/mnt/immunogenomics/RUNS/run49/data/': ['GHW6GYB01.sff', 'GHW6GYB02.sff'],
#  '/mnt/immunogenomics/RUNS/run51/data/': ['GI3GR6H01.sff', 'GI3GR6H02.sff'],
#  '/mnt/immunogenomics/RUNS/run55/data/': ['GK7M7SC01.sff',
#   'GK7M7SC02.sff',
#   'GK7M7SC03.sff',
#   'GK7M7SC04.sff',
#   'GK7M7SC05.sff'],
#  '/mnt/immunogenomics/RUNS/run58/data/': ['GMUTUER01.sff', 'GMUTUER02.sff'],
#  '/mnt/immunogenomics/RUNS/run61/data/': ['GPR83OS01.sff',
#   'GPR83OS02.sff',
#   'GPR83OS03.sff',
#   'GPR83OS04.sff',
#   'GPR83OS05.sff'],
#  '/mnt/immunogenomics/RUNS/run70/data/': ['GS96CJ301.sff', 'GS96CJ302.sff'],
#  '/mnt/immunogenomics/RUNS/run71/data/': ['GVHSAYA01.sff', 'GVHSAYA02.sff']}

# %%
fhSamples = open("SAMPLES-sff", "w")
fhRename = open("rename_files.sh", "w")
for mydir, myfiles in download_sff.items():
    run = mydir.split("/")[4]
    #print(run)
    for myfile in myfiles:
        region, ext = myfile.split(".")
        region = region[-1]
        mypath = mydir + myfile
        print(run, region, mypath)
        print(mypath, file=fhSamples)
        print("mv", myfile, run + "-r" + str(region) + "-" + myfile.split(".")[0] + "_S" + str(region) + "_L001.assembled.sff", file=fhRename)
fhSamples.close()
fhRename.close()
# Out:
# run102 1 /mnt/immunogenomics/RUNS/run102/data/HA06QXN01.sff
# run102 2 /mnt/immunogenomics/RUNS/run102/data/HA06QXN02.sff
# run114 1 /mnt/immunogenomics/RUNS/run114/data/HHEXEGX01.sff
# run114 2 /mnt/immunogenomics/RUNS/run114/data/HHEXEGX02.sff
# run114 3 /mnt/immunogenomics/RUNS/run114/data/HHEXEGX03.sff
# run114 4 /mnt/immunogenomics/RUNS/run114/data/HHEXEGX04.sff
# run122 1 /mnt/immunogenomics/RUNS/run122/data/HI7M9GL01.sff
# run122 2 /mnt/immunogenomics/RUNS/run122/data/HI7M9GL02.sff
# run162 1 /mnt/immunogenomics/RUNS/run162/data/HV4JT6A01.sff
# run162 2 /mnt/immunogenomics/RUNS/run162/data/HV4JT6A02.sff
# run183 1 /mnt/immunogenomics/RUNS/run183/data/H4W1I3K01.sff
# run183 2 /mnt/immunogenomics/RUNS/run183/data/H4W1I3K02.sff
# run211 1 /mnt/immunogenomics/RUNS/run211/data/IC7F61C01.sff
# run211 2 /mnt/immunogenomics/RUNS/run211/data/IC7F61C02.sff
# run239 1 /mnt/immunogenomics/RUNS/run239/data/ITW40QN01.sff
# run239 2 /mnt/immunogenomics/RUNS/run239/data/ITW40QN02.sff
# run24 1 /mnt/immunogenomics/RUNS/run24/data/FVUGYZ001.sff
# run24 2 /mnt/immunogenomics/RUNS/run24/data/FVUGYZ002.sff
# run24 3 /mnt/immunogenomics/RUNS/run24/data/FVUGYZ003.sff
# run24 4 /mnt/immunogenomics/RUNS/run24/data/FVUGYZ004.sff
# run241 2 /mnt/immunogenomics/RUNS/run241/data/IWAB1T402.sff
# run242 1 /mnt/immunogenomics/RUNS/run242/data/IXKJMGP01.sff
# run242 2 /mnt/immunogenomics/RUNS/run242/data/IXKJMGP02.sff
# run243 1 /mnt/immunogenomics/RUNS/run243/data/I0EK49M01.sff
# run243 2 /mnt/immunogenomics/RUNS/run243/data/I0EK49M02.sff
# run246 1 /mnt/immunogenomics/RUNS/run246/data/I4IMECA01.sff
# run246 2 /mnt/immunogenomics/RUNS/run246/data/I4IMECA02.sff
# run252 1 /mnt/immunogenomics/RUNS/run252/data/JFBFA9N01.sff
# run252 2 /mnt/immunogenomics/RUNS/run252/data/JFBFA9N02.sff
# run254 1 /mnt/immunogenomics/RUNS/run254/data/JI6EKIL01.sff
# run254 2 /mnt/immunogenomics/RUNS/run254/data/JI6EKIL02.sff
# run259 1 /mnt/immunogenomics/RUNS/run259/data/JV3AIYM01.sff
# run259 2 /mnt/immunogenomics/RUNS/run259/data/JV3AIYM02.sff
# run27 1 /mnt/immunogenomics/RUNS/run27/data/F3EL0MZ01.sff
# run34 1 /mnt/immunogenomics/RUNS/run34/data/F6SXVTI01.sff
# run34 2 /mnt/immunogenomics/RUNS/run34/data/F6SXVTI02.sff
# run37 1 /mnt/immunogenomics/RUNS/run37/data/GAIEXSY01.sff
# run37 2 /mnt/immunogenomics/RUNS/run37/data/GAIEXSY02.sff
# run37 3 /mnt/immunogenomics/RUNS/run37/data/GAIEXSY03.sff
# run37 4 /mnt/immunogenomics/RUNS/run37/data/GAIEXSY04.sff
# run41 1 /mnt/immunogenomics/RUNS/run41/data/GB5HR3001.sff
# run41 2 /mnt/immunogenomics/RUNS/run41/data/GB5HR3002.sff
# run41 3 /mnt/immunogenomics/RUNS/run41/data/GB5HR3003.sff
# run41 4 /mnt/immunogenomics/RUNS/run41/data/GB5HR3004.sff
# run45 1 /mnt/immunogenomics/RUNS/run45/data/GFAGD2L01.sff
# run45 2 /mnt/immunogenomics/RUNS/run45/data/GFAGD2L02.sff
# run49 1 /mnt/immunogenomics/RUNS/run49/data/GHW6GYB01.sff
# run49 2 /mnt/immunogenomics/RUNS/run49/data/GHW6GYB02.sff
# run51 1 /mnt/immunogenomics/RUNS/run51/data/GI3GR6H01.sff
# run51 2 /mnt/immunogenomics/RUNS/run51/data/GI3GR6H02.sff
# run55 1 /mnt/immunogenomics/RUNS/run55/data/GK7M7SC01.sff
# run55 2 /mnt/immunogenomics/RUNS/run55/data/GK7M7SC02.sff
# run55 3 /mnt/immunogenomics/RUNS/run55/data/GK7M7SC03.sff
# run55 4 /mnt/immunogenomics/RUNS/run55/data/GK7M7SC04.sff
# run55 5 /mnt/immunogenomics/RUNS/run55/data/GK7M7SC05.sff
# run58 1 /mnt/immunogenomics/RUNS/run58/data/GMUTUER01.sff
# run58 2 /mnt/immunogenomics/RUNS/run58/data/GMUTUER02.sff
# run61 1 /mnt/immunogenomics/RUNS/run61/data/GPR83OS01.sff
# run61 2 /mnt/immunogenomics/RUNS/run61/data/GPR83OS02.sff
# run61 3 /mnt/immunogenomics/RUNS/run61/data/GPR83OS03.sff
# run61 4 /mnt/immunogenomics/RUNS/run61/data/GPR83OS04.sff
# run61 5 /mnt/immunogenomics/RUNS/run61/data/GPR83OS05.sff
# run70 1 /mnt/immunogenomics/RUNS/run70/data/GS96CJ301.sff
# run70 2 /mnt/immunogenomics/RUNS/run70/data/GS96CJ302.sff
# run71 1 /mnt/immunogenomics/RUNS/run71/data/GVHSAYA01.sff
# run71 2 /mnt/immunogenomics/RUNS/run71/data/GVHSAYA02.sff

# %% [markdown]
# ## Notes
# The SAMPLES-sff file can be renamed to SAMPLES. Then run ../copy-from-beehub.sh
#
# The downloaded files can be renamed with the script that was produced above: bash rename-files.sh
#
# TO DO: generate a script that will convert the sff file to fastq and upload this to the ResearchDrive in the right directory: python2 ../SeqToFastq.py sff *.sff
